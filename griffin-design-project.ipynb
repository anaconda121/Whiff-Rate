# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# 'vx0', 'vy0', 'vz0', 'x', 'x0', 'y', 'y0', 'z0'
# Out:
#   File "<ipython-input-4-df056c13da02>", line 5
#     |
#     ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv("pitches.csv")

# %%
df.columns
# Out:
# Index(['px', 'pz', 'start_speed', 'end_speed', 'spin_rate', 'spin_dir',
#        'break_angle', 'break_length', 'break_y', 'ax', 'ay', 'az', 'sz_bot',
#        'sz_top', 'type_confidence', 'vx0', 'vy0', 'vz0', 'x', 'x0', 'y', 'y0',
#        'z0', 'pfx_x', 'pfx_z', 'nasty', 'zone', 'code', 'type', 'pitch_type',
#        'event_num', 'b_score', 'ab_id', 'b_count', 's_count', 'outs',
#        'pitch_num', 'on_1b', 'on_2b', 'on_3b'],
#       dtype='object')

# %%
# drop balls, bunts, pitchouts
df = df[df.code.isin(['S', 'C', 'F', 'T', 'W', 'H', 'X', 'D', 'E'])]

# %%
df["code"]
# Out:
# 0          C
# 1          S
# 2          F
# 5          X
# 7          D
# 10         E
# 11         F
# 12         F
# 13         S
# 15         F
# 16         F
# 17         F
# 18         S
# 20         D
# 21         F
# 23         S
# 24         X
# 26         S
# 27         C
# 29         C
# 32         F
# 33         X
# 35         S
# 36         S
# 37         S
# 38         S
# 42         S
# 43         F
# 45         F
# 46         F
#           ..
# 2867112    C
# 2867113    F
# 2867114    F
# 2867115    F
# 2867117    S
# 2867119    T
# 2867120    X
# 2867121    C
# 2867122    D
# 2867125    C
# 2867126    X
# 2867128    F
# 2867129    D
# 2867131    S
# 2867132    X
# 2867133    C
# 2867134    S
# 2867135    F
# 2867136    S
# 2867137    F
# 2867140    X
# 2867144    C
# 2867145    C
# 2867146    F
# 2867147    F
# 2867148    F
# 2867149    D
# 2867151    F
# 2867152    S
# 2867153    X
# Name: code, Length: 1814931, dtype: object

# %% [markdown]
# # vx0, vy0, vz0

# %%
sns.displot(df["vx0"])

# %%
sns.displot(df["vy0"])

# note that y in here represents velocity from base to hitter, not vertical velocity. 
# that's why it's around 120 while x and z are around -10 to 10

# %%
sns.displot(df["vz0"])

# %%
sns.boxplot(x=df["code"], y = df["vx0"])

# %%
sns.boxplot(x=df["code"], y = df["vy0"])

# %%
sns.boxplot(x=df["code"], y = df["vz0"])

# %% [markdown]
# # x0, y0, z0

# %%
sns.displot(df["x0"])

# %%
sns.displot(df["y0"])

# %%
sns.displot(df["z0"])

# %%
sns.boxplot(x=df["code"], y = df["x0"])

# %%
sns.boxplot(x=df["code"], y = df["y0"])

# %%
sns.boxplot(x=df["code"], y = df["z0"])

# %% [markdown]
# # x, y
#
# ## These are only used in stadiums without PITCHf/x

# %%
sns.displot(df["x"])

# %%
sns.displot(df["y"])

# %%
sns.boxplot(x=df["code"], y = df["x"])

# %%
sns.boxplot(x=df["code"], y = df["y"])

# %% [markdown]
# # Other stuff

# %%
sns.countplot(df["type"])
# Out:
# /usr/local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.scatterplot(x=df["type"], y=df["start_speed"])

# %%
sns.scatterplot(x=df["type"], y=df["spin_rate"])

# %%
sns.scatterplot(x=df["type"], y=df["spin_dir"])

# %%
sns.boxplot(x=df["type"], y = df["start_speed"])

# %%
sns.boxplot(x=df["type"], y = df["spin_rate"])

# %%
sns.boxplot(x=df["zone"], y = df["type"])

# %%
sns.boxplot(x=df["vx0"], y = df["type"])
